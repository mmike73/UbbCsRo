# %%
from random import choices, sample
from math import comb, perm
#1
#i

def estimareProbabilitate(red, blue, green, repet, num):
    urna = red * ['r'] + blue * ['b'] + green * ['g'];

    print(urna)
    cntA = 0
    cntAB = 0
    
    for _ in range(repet):
        extrase = sample(urna, num)
        unice = set(extrase)

        if "r" in extrase:
            cntA += 1
            if len(unice) == 1:
                cntAB += 1
    print(cntA , cntAB)
    return float(cntAB / cntA)

# %%
estimareProbabilitate(5,3,2,100000,3)
# Out:
# ['r', 'r', 'r', 'r', 'r', 'b', 'b', 'b', 'g', 'g']
# 91727 8383
# 0.09139075735606746

# %%
#ii

# %%
#2
from random import randrange
from matplotlib.pyplot import bar, hist, grid, show, legend

data = [randrange(1,7) for _ in range(500)]
bin_edges = [k+0.5 for k in range(7)]
hist(data, bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black',
        alpha = 0.5, label = 'frecvente relative')

distribution = dict([(k,1/6) for k in range(1,7)])
bar(distribution.keys(), distribution.values(), width = 0.85, color = 'red', edgecolor = 'black',
        alpha= 0.6, label = 'probabilitati')

legend(loc = 'lower left')
grid()
show()

# %%
#3
from scipy.stats import binom

# %%
x = binom.rvs(5, 0.6, size=1000)#nr_sim
x
# Out:
# array([4, 2, 2, 2, 3, 3, 3, 5, 0, 3, 1, 2, 1, 3, 3, 5, 3, 2, 2, 4, 5, 2,
#        3, 2, 2, 3, 4, 4, 3, 4, 2, 1, 3, 2, 3, 3, 3, 4, 4, 2, 4, 1, 1, 2,
#        3, 4, 4, 1, 3, 1, 3, 3, 2, 3, 4, 4, 3, 2, 3, 2, 1, 3, 3, 3, 3, 4,
#        2, 2, 3, 4, 2, 4, 2, 3, 5, 4, 2, 3, 3, 3, 3, 4, 1, 1, 4, 2, 3, 4,
#        4, 4, 3, 3, 1, 3, 4, 3, 4, 2, 4, 3, 4, 3, 1, 3, 4, 4, 4, 3, 4, 2,
#        3, 1, 4, 2, 3, 3, 4, 3, 5, 2, 3, 2, 5, 3, 3, 5, 4, 3, 2, 4, 4, 3,
#        3, 4, 3, 3, 3, 5, 2, 2, 3, 3, 1, 1, 4, 3, 3, 3, 2, 4, 3, 3, 4, 2,
#        5, 3, 3, 5, 3, 1, 2, 3, 1, 3, 1, 4, 3, 3, 1, 1, 0, 4, 4, 3, 3, 4,
#        4, 4, 4, 1, 4, 5, 2, 3, 1, 3, 5, 4, 4, 4, 4, 1, 5, 2, 4, 4, 3, 3,
#        5, 4, 4, 4, 2, 2, 2, 3, 3, 5, 0, 3, 4, 2, 2, 2, 5, 3, 2, 4, 3, 2,
#        4, 2, 2, 2, 3, 3, 3, 4, 5, 4, 4, 3, 3, 4, 3, 1, 4, 2, 3, 2, 3, 4,
#        2, 5, 3, 5, 3, 5, 2, 4, 4, 5, 3, 1, 5, 3, 2, 1, 2, 1, 2, 3, 1, 2,
#        3, 3, 4, 4, 3, 3, 5, 2, 1, 2, 4, 4, 4, 3, 2, 3, 4, 4, 2, 4, 1, 3,
#        2, 3, 3, 2, 4, 3, 4, 5, 2, 2, 2, 3, 4, 3, 4, 2, 1, 1, 4, 3, 4, 5,
#        4, 4, 2, 5, 2, 3, 2, 4, 3, 4, 2, 5, 4, 3, 4, 3, 2, 4, 3, 3, 3, 4,
#        3, 3, 3, 4, 3, 3, 2, 1, 3, 4, 3, 3, 2, 2, 3, 3, 1, 4, 2, 4, 0, 4,
#        3, 3, 4, 1, 5, 4, 2, 4, 2, 4, 5, 1, 2, 3, 2, 2, 5, 4, 3, 4, 2, 3,
#        2, 3, 1, 2, 3, 2, 1, 3, 3, 4, 3, 3, 3, 2, 1, 5, 1, 4, 4, 3, 2, 3,
#        5, 4, 1, 4, 3, 5, 2, 2, 5, 5, 2, 2, 2, 3, 4, 3, 3, 3, 3, 4, 2, 4,
#        4, 2, 4, 2, 5, 5, 4, 2, 4, 1, 4, 2, 2, 3, 2, 3, 4, 3, 3, 4, 1, 4,
#        2, 4, 4, 5, 2, 5, 2, 2, 3, 3, 2, 2, 4, 3, 4, 3, 3, 2, 2, 3, 1, 3,
#        2, 2, 4, 2, 1, 3, 3, 2, 2, 5, 3, 4, 4, 4, 1, 3, 3, 3, 3, 3, 2, 4,
#        3, 4, 4, 2, 4, 3, 4, 4, 3, 2, 3, 2, 2, 4, 3, 2, 3, 3, 4, 4, 4, 1,
#        3, 3, 4, 4, 4, 3, 2, 5, 4, 3, 2, 4, 3, 3, 5, 3, 3, 2, 4, 5, 2, 4,
#        4, 2, 2, 3, 2, 2, 2, 4, 4, 4, 0, 2, 4, 4, 4, 4, 3, 4, 3, 0, 3, 2,
#        2, 4, 4, 2, 4, 3, 3, 1, 2, 3])

# %%
#0.6 - probabilitate de succes
#5 - nr de extrageri
bin_edges = [k+0.5 for k in range(-1, 6)]
hist(x, bin_edges, density = True, rwidth = 0.9, color = 'green', edgecolor = 'black',
        alpha = 0.5, label = 'frecvente relative')

distribution = dict([(k,binom.pmf(k, 5, 0.6)) for k in range(6)])
bar(distribution.keys(), distribution.values(), width = 0.85, color = 'red', edgecolor = 'black',
        alpha= 0.6, label = 'probabilitati')

legend(loc = 'lower left')
grid()
show()
